# %% [markdown]
# <a href="https://colab.research.google.com/github/kev841/python-projects/blob/main/Linearregression_with_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('/content/1.01.+Simple+linear+regression (1).csv')
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
x = data['SAT']
y = data['GPA']

# %%
x.shape
# Out:
# (84,)

# %%
y.shape
# Out:
# (84,)

# %%
x_matrix = x.values.reshape(-1,1)
x_matrix.shape
# Out:
# (84, 1)

# %%
reg = LinearRegression()
reg.fit(x_matrix,y)
# Out:
# LinearRegression()

# %% [markdown]
# Finding the r squared

# %%
reg.score(x_matrix,y)
# Out:
# 0.40600391479679754

# %% [markdown]
# finding coef

# %%
reg.coef_
# Out:
# array([0.00165569])

# %%
reg.intercept_
# Out:
# np.float64(0.2750402996602799)

# %%
new_data = pd.DataFrame(data=[1740,1760],columns=['SAT'])
new_data
# Out:
#     SAT
# 0  1740
# 1  1760

# %%
new_data['Predicted_GPA'] = reg.predict(new_data)
new_data
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
#     SAT  Predicted_GPA
# 0  1740       3.155938
# 1  1760       3.189051

# %%
plt.scatter(x,y)
yhat = reg.coef_*x_matrix + reg.intercept_
fig = plt.plot(x,yhat, lw=4, c='orange', label ='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()
